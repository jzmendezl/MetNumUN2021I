# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        #Select NVDA minute resolution data and set it to Raw normalization mode
        self.nvda = self.AddEquity("NVDA", Resolution.Minute)
        self.nvda.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):
        
        #Place an order for 100 shares of NVDA and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("NVDA", 100)
            
            #Debug the AveragePrice of NVDA
            self.Debug(str(self.Portfolio["NVDA"].AveragePrice))

# %%
#NVDA
# %%html
<iframe src="https://drive.google.com/file/d/1XibzI8MjbnmtdiVlpsRtr5zl4I_ypakp/preview" width="640" height="480"></iframe>
# Out:
# <iframe src="https://drive.google.com/file/d/1XibzI8MjbnmtdiVlpsRtr5zl4I_ypakp/preview" width="640" height="480"></iframe>

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        #Select TSLA minute resolution data and set it to Raw normalization mode
        self.tsla = self.AddEquity("TSLA", Resolution.Minute)
        self.tsla.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):
        
        #Place an order for 100 shares of TSLA and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("TSLA", 100)
            
            #Debug the AveragePrice of TSLA
            self.Debug(str(self.Portfolio["TSLA"].AveragePrice))

# %%
#TSLA
# %%html
<iframe src="https://drive.google.com/file/d/19txjlNKZx-7YXO9SnFyNqQVHV9r5EgBe/preview" width="640" height="480"></iframe>
# Out:
# <iframe src="https://drive.google.com/file/d/19txjlNKZx-7YXO9SnFyNqQVHV9r5EgBe/preview" width="640" height="480"></iframe>

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        #Select DIS minute resolution data and set it to Raw normalization mode
        self.dis = self.AddEquity("DIS", Resolution.Minute)
        self.dis.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):
        
        #Place an order for 100 shares of DIS and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("DIS", 100)
            
            #Debug the AveragePrice of DIS
            self.Debug(str(self.Portfolio["DIS"].AveragePrice))

# %%
#DIS
# %%html
<iframe src="https://drive.google.com/file/d/13CgckkwedoSYkPeW967_6pGbqAgLkiq9/preview" width="640" height="480"></iframe>
# Out:
# <iframe src="https://drive.google.com/file/d/13CgckkwedoSYkPeW967_6pGbqAgLkiq9/preview" width="640" height="480"></iframe>

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        #Select AMZN minute resolution data and set it to Raw normalization mode
        self.amzn = self.AddEquity("AMZN", Resolution.Minute)
        self.amzn.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):
        
        #Place an order for 100 shares of AMZN and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("AMZN", 100)
            
            #Debug the AveragePrice of AMZN
            self.Debug(str(self.Portfolio["AMZN"].AveragePrice))

# %%
#AMZN
# %%html
<iframe src="https://drive.google.com/file/d/18LA_PhxcOgpR6wv4x8dBtWAi_O2j8WBu/preview" width="640" height="480"></iframe>

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2019, 1, 1)
        self.SetEndDate(2021, 1, 1)

        #Select GOOG minute resolution data and set it to Raw normalization mode
        self.goog = self.AddEquity("GOOG", Resolution.Minute)
        self.goog.SetDataNormalizationMode(DataNormalizationMode.Raw)
        

    def OnData(self, data):
        
        #Place an order for 100 shares of GOOG and print the average fill price
        if not self.Portfolio.Invested:
            self.MarketOrder("GOOG", 100)
            
            #Debug the AveragePrice of DIS
            self.Debug(str(self.Portfolio["GOOG"].AveragePrice))

# %%
#GOOG
# %%html
<iframe src="https://drive.google.com/file/d/1LVQ4z_4Ws_jgdz46WhVxV4KLnzBLxJ3B/preview" width="640" height="480"></iframe>
# Out:
# <iframe src="https://drive.google.com/file/d/1LVQ4z_4Ws_jgdz46WhVxV4KLnzBLxJ3B/preview" width="640" height="480"></iframe>
