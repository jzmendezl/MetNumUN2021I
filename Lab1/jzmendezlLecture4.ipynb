# %% [markdown]
# # Introduction to pandas
# by Maxwell Margenot
#
# Part of the Quantopian Lecture Series:
#
# * [www.quantopian.com/lectures](https://www.quantopian.com/lectures)
# * [github.com/quantopian/research_public](https://github.com/quantopian/research_public)

# %% [markdown]
# pandas is a Python library that provides a collection of powerful data structures to better help you manage data. In this lecture, we will cover how to use the `Series` and `DataFrame` objects to handle data. These objects have a strong integration with NumPy, covered elsewhere in the [lecture series](http://www.quantopian.com/lectures#Introduction-to-NumPy), allowing us to easily do the necessary statistical and mathematical calculations that we need for finance.

# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# With pandas, it is easy to store, visualize, and perform calculations on your data. With only a few lines of code we can modify our data and present it in an easily-understandable way. Here we simulate some returns in NumPy, put them into a pandas `DataFrame`, and perform calculations to turn them into prices and plot them, all only using a few lines of code.

# %%
returns = pd.DataFrame(np.random.normal(1.0, 0.03, (100, 10)))
prices = returns.cumprod()
prices.plot()
plt.title('Randomly-generated Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend(loc=0);

# %%
returns
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.990634  1.013335  0.999803  1.018673  0.969609  1.007709  0.973722
# 1   1.003140  1.031531  1.029279  1.024203  0.968806  1.000827  0.994029
# 2   1.049059  1.016537  0.990010  1.023018  1.049495  0.994587  1.028300
# 3   0.989121  0.933140  0.960849  0.991101  0.988386  0.997691  1.019566
# 4   1.007319  0.993553  0.986507  1.020323  1.004202  0.968335  1.010897
# 5   0.993673  0.989762  1.026318  1.005795  0.992738  1.006009  0.954751
# 6   0.966429  1.029299  1.005717  1.013967  0.999413  1.018633  1.007136
# 7   0.949657  0.960245  0.952800  0.959156  0.982619  1.056981  0.966105
# 8   0.982013  1.009953  1.024945  0.986567  0.963401  0.989667  0.981650
# 9   1.070775  1.019136  0.983878  1.063577  1.032079  0.987846  1.016839
# 10  0.944105  0.971388  0.957668  0.948977  1.038653  0.976756  0.977272
# 11  0.999852  1.017199  0.988208  1.023368  1.012483  1.001336  1.008473
# ...

# %%
ret = pd.DataFrame(np.random.normal(1.025, 0.04, (100, 10)))
prcs = ret.cumprod()
prcs.plot()
plt.title('Precios Geerados Aleatoriamente')
plt.xlabel('Tiempo')
plt.ylabel('Precio')
plt.legend();

# %% [markdown]
# So let's have a look at how we actually build up to this point!

# %% [markdown]
# ## pandas Data Structures
#
# ### `Series`
#
# A pandas `Series` is a 1-dimensional array with labels that can contain any data type. We primarily use them for handling time series data. Creating a `Series` is as easy as calling `pandas.Series()` on a Python list or NumPy array.

# %%
#Se cambia la declaracion a Python3
s = pd.Series([1, 2, np.nan, 4, 5])
print (s)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# dtype: float64

# %%
sr = pd.Series([2, 5, np.nan, 3.8, 5.2, np.nan])
print (sr)
# Out:
# 0    2.0
# 1    5.0
# 2    NaN
# 3    3.8
# 4    5.2
# 5    NaN
# dtype: float64

# %% [markdown]
# Every `Series` has a name. We can give the series a name as a parameter or we can define it afterwards by directly accessing the name attribute. In this case, we have given our time series no name so the attribute should be empty.

# %%
#Se cambia la declaracion a Python3
print (s.name)
# Out:
# None

# %%
print (sr.name)
# Out:
# None

# %% [markdown]
# This name can be directly modified with no repercussions.

# %%
#Se cambia la declaracion a Python3
s.name = "Toy Series"
print (s.name)
# Out:
# Toy Series

# %%
sr.name = 'Series de Prueba'
print (sr.name)
# Out:
# Series de Prueba

# %% [markdown]
# We call the collected axis labels of a `Series` its index. An index can either passed to a `Series` as a parameter or added later, similarly to its name. In the absence of an index, a `Series` will simply contain an index composed of integers, starting at $0$, as in the case of our "Toy Series".

# %%
#Se cambia la declaracion a Python3
print (s.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print (sr.index)
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# pandas has a built-in function specifically for creating date indices, `date_range()`. We use the function here to create a new index for `s`.

# %%
#Se cambia la declaracion a Python3
new_index = pd.date_range("2016-01-01", periods=len(s), freq="D")
print (new_index)
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
index_1 = pd.date_range('2021-01-01', periods=len(sr), freq= 'D')
print (index_1)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# An index must be exactly the same length as the `Series` itself. Each index must match one-to-one with each element of the `Series`. Once this is satisfied, we can directly modify the `Series` index, as with the name, to use our new and more informative index (relatively speaking).

# %%
#Se cambia la declaracion a Python3
s.index = new_index
print (s.index)
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
sr.index = index_1
print (sr.index)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# The index of the `Series` is crucial for handling time series, which we will get into a little later.

# %% [markdown]
# #### Accessing `Series` Elements
#
# `Series` are typically accessed using the `iloc[]` and `loc[]` methods. We use `iloc[]` to access elements by integer index and we use `loc[]` to access the index of the Series.

# %%
#Se cambia la declaracion a Python3
print ("First element of the series: ", s.iloc[0])
print ("Last element of the series: ", s.iloc[len(s)-1])
# Out:
# ('First element of the series: ', 1.0)
# ('Last element of the series: ', 5.0)

# %%
print ('El elemento 2 de la serie es: ', sr.iloc[1])
print ('El penultino elemento de la serie es: ', sr.iloc[len(sr)-2])
# Out:
# ('El elemento 2 de la serie es: ', 5.0)
# ('El penultino elemento de la serie es: ', 5.2)

# %% [markdown]
# We can slice a `Series` similarly to our favorite collections, Python lists and NumPy arrays. We use the colon operator to indicate the slice.

# %%
s.iloc[:2]
# Out:
# 2016-01-01    1.0
# 2016-01-02    2.0
# Freq: D, Name: Toy Series, dtype: float64

# %%
sr.iloc[:len(sr)]
# Out:
# 2021-01-01    2.0
# 2021-01-02    5.0
# 2021-01-03    NaN
# 2021-01-04    3.8
# 2021-01-05    5.2
# 2021-01-06    NaN
# Freq: D, Name: Series de Prueba, dtype: float64

# %%
sr.iloc[::]
# Out:
# 2021-01-01    2.0
# 2021-01-02    5.0
# 2021-01-03    NaN
# 2021-01-04    3.8
# 2021-01-05    5.2
# 2021-01-06    NaN
# Freq: D, Name: Series de Prueba, dtype: float64

# %% [markdown]
# When creating a slice, we have the options of specifying a beginning, an end, and a step. The slice will begin at the start index, and take steps of size `step` until it passes the end index, not including the end.

# %%
start = 0
end = len(s) - 1
step = 1

s.iloc[start:end:step]
# Out:
# 2016-01-01    1.0
# 2016-01-02    2.0
# 2016-01-03    NaN
# 2016-01-04    4.0
# Freq: D, Name: Toy Series, dtype: float64

# %%
sr.iloc[0:len(sr)-1:1]
# Out:
# 2021-01-01    2.0
# 2021-01-02    5.0
# 2021-01-03    NaN
# 2021-01-04    3.8
# 2021-01-05    5.2
# Freq: D, Name: Series de Prueba, dtype: float64

# %% [markdown]
# We can even reverse a `Series` by specifying a negative step size. Similarly, we can index the start and end with a negative integer value.

# %%
s.iloc[::-1]
# Out:
# 2016-01-05    5.0
# 2016-01-04    4.0
# 2016-01-03    NaN
# 2016-01-02    2.0
# 2016-01-01    1.0
# Freq: -1D, Name: Toy Series, dtype: float64

# %%
sr.iloc[::-1]
# Out:
# 2021-01-06    NaN
# 2021-01-05    5.2
# 2021-01-04    3.8
# 2021-01-03    NaN
# 2021-01-02    5.0
# 2021-01-01    2.0
# Freq: -1D, Name: Series de Prueba, dtype: float64

# %% [markdown]
# This returns a slice of the series that starts from the second to last element and ends at the third to last element (because the fourth to last is not included, taking steps of size $1$).

# %%
s.iloc[-2:-4:-1]
# Out:
# 2016-01-04    4.0
# 2016-01-03    NaN
# Freq: -1D, Name: Toy Series, dtype: float64

# %%
sr.iloc[-1:-3:-1]
# Out:
# 2021-01-06    NaN
# 2021-01-05    5.2
# Freq: -1D, Name: Series de Prueba, dtype: float64

# %% [markdown]
# We can also access a series by using the values of its index. Since we indexed `s` with a collection of dates (`Timestamp` objects) we can look at the value contained in `s` for a particular date.

# %%
s.loc['2016-01-01']
# Out:
# 1.0

# %%
sr.loc['2021-01-5']
# Out:
# 5.2

# %% [markdown]
# Or even for a range of dates!

# %%
s.loc['2016-01-02':'2016-01-04']
# Out:
# 2016-01-02    2.0
# 2016-01-03    NaN
# 2016-01-04    4.0
# Freq: D, Name: Toy Series, dtype: float64

# %%
sr.loc['2021-01-01':'2021-01-05']
# Out:
# 2021-01-01    2.0
# 2021-01-02    5.0
# 2021-01-03    NaN
# 2021-01-04    3.8
# 2021-01-05    5.2
# Freq: D, Name: Series de Prueba, dtype: float64

# %% [markdown]
# With `Series`, we *can* just use the brackets (`[]`) to access elements, but this is not best practice. The brackets are ambiguous because they can be used to access `Series` (and `DataFrames`) using both index and integer values and the results will change based on context (especially with `DataFrames`).

# %% [markdown]
# #### Boolean Indexing
#
# In addition to the above-mentioned access methods, you can filter `Series` using boolean arrays. `Series` are compatible with your standard comparators. Once compared with whatever condition you like, you get back yet another `Series`, this time filled with boolean values.

# %% [markdown]
# Una tabla de verdad, o tabla de valores de verdades, es una tabla que muestra el valor de verdad de una proposición compuesta, para cada combinación de verdad que se pueda asignar.
#
# ${\displaystyle {\begin{array}{|c|c|c|}\hline A&B&A\land B\\\hline V&V&V\\V&F&F\\F&V&F\\F&F&F\\\hline \end{array}}}$
# ${\displaystyle {\begin{array}{|c|c|c|}\hline A&B&A\lor B\\\hline V&V&V\\V&F&V\\F&V&V\\F&F&F\\\hline \end{array}}}$
# ${\displaystyle {\begin{array}{|c|c|c|}\hline A&B&A\Rightarrow B\\\hline V&V&V\\V&F&F\\F&V&V\\F&F&V\\\hline \end{array}}}$
# ${\displaystyle {\begin{array}{|c|c|c|}\hline A&B&A\Leftrightarrow B\\\hline V&V&V\\V&F&F\\F&V&F\\F&F&V\\\hline \end{array}}}$

# %%
#Se cambia la declaracion a Python3
print (s < 3)
# Out:
# 2016-01-01     True
# 2016-01-02     True
# 2016-01-03    False
# 2016-01-04    False
# 2016-01-05    False
# Freq: D, Name: Toy Series, dtype: bool

# %%
print (sr > 2)
# Out:
# 2021-01-01    False
# 2021-01-02     True
# 2021-01-03    False
# 2021-01-04     True
# 2021-01-05     True
# 2021-01-06    False
# Freq: D, Name: Series de Prueba, dtype: bool

# %% [markdown]
# We can pass *this* `Series` back into the original `Series` to filter out only the elements for which our condition is `True`.

# %%
#Se cambia la declaracion a Python3
print (s.loc[s < 3])
# Out:
# 2016-01-01    1.0
# 2016-01-02    2.0
# Freq: D, Name: Toy Series, dtype: float64

# %%
print (sr.loc[sr > 2])
# Out:
# 2021-01-02    5.0
# 2021-01-04    3.8
# 2021-01-05    5.2
# Name: Series de Prueba, dtype: float64

# %% [markdown]
#  If we so desire, we can group multiple conditions together using the logical operators `&`, `|`, and `~` (and, or, and not, respectively).

# %%
#Se cambia la declaracion a Python3
print (s.loc[(s < 3) & (s > 1)])
# Out:
# 2016-01-02    2.0
# Freq: D, Name: Toy Series, dtype: float64

# %%
print (sr.loc[((sr >1)|(sr < 3)) & (~(sr < 5))])
# Out:
# 2021-01-02    5.0
# 2021-01-05    5.2
# Freq: 3D, Name: Series de Prueba, dtype: float64

# %% [markdown]
# This is very convenient for getting only elements of a `Series` that fulfill specific criteria that we need. It gets even more convenient when we are handling `DataFrames`.

# %% [markdown]
# #### Indexing and Time Series
#
# Since we use `Series` for handling time series, it's worth covering a little bit of how we handle the time component. For our purposes we use pandas `Timestamp` objects. Let's pull a full time series, complete with all the appropriate labels, by using our `get_pricing()` method. All data pulled with `get_pricing()` or using our Pipeline API will be in either `Series` or `DataFrame` format. We can modify this index however we like.

# %%
import fix_yahoo_finance as fyf
from pandas_datareader import data as pdr

# %%
fyf.pdr_override()

# %%
symbol = "CMG"
start = dt.date (2012, 01, 01)
end = dt.date (2016, 01, 01)
prices = pdr.get_data_yahoo(symbol, start, end)['Adj Close']
#prices = get_pricing(symbol, start_date=start, end_date=end, fields="price")
#get_pricing se encuentra en deshuso
print (prices)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# Date
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-09    339.739990
# 2012-01-10    341.119995
# 2012-01-11    347.600006
# 2012-01-12    347.619995
# 2012-01-13    354.619995
# 2012-01-17    353.380005
# 2012-01-18    356.820007
# 2012-01-19    358.089996
# 2012-01-20    356.390015
# 2012-01-23    360.459991
# 2012-01-24    360.600006
# 2012-01-25    363.140015
# 2012-01-26    365.809998
# 2012-01-27    366.760010
# 2012-01-30    367.690002
# 2012-01-31    367.290009
# 2012-02-01    370.410004
# 2012-02-02    362.820007
# 2012-02-03    372.190002
# 2012-02-06    371.630005
# 2012-02-07    374.019989
# 2012-02-08    374.019989
# 2012-02-09    376.489990
# 2012-02-10    376.450012
# 2012-02-13    377.450012
# 2012-02-14    378.940002
#                  ...
# 2015-11-18    594.000000
# 2015-11-19    611.510010
# 2015-11-20    536.190002
# ...

# %%
tck = 'AMZN'
inicio = dt.datetime(2016, 01, 01)
fin = dt.datetime(2021, 01, 01)
precios = pdr.get_data_yahoo(tck, start, end)['Adj Close']
print (precios, type(precios))
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# (Date
# 2012-01-03    179.029999
# 2012-01-04    177.509995
# 2012-01-05    177.610001
# 2012-01-06    182.610001
# 2012-01-09    178.559998
# 2012-01-10    179.339996
# 2012-01-11    178.899994
# 2012-01-12    175.929993
# 2012-01-13    178.419998
# 2012-01-17    181.660004
# 2012-01-18    189.440002
# 2012-01-19    194.449997
# 2012-01-20    190.929993
# 2012-01-23    186.089996
# 2012-01-24    187.000000
# 2012-01-25    187.800003
# 2012-01-26    193.320007
# 2012-01-27    195.369995
# 2012-01-30    192.149994
# 2012-01-31    194.440002
# 2012-02-01    179.460007
# 2012-02-02    181.720001
# 2012-02-03    187.679993
# 2012-02-06    183.139999
# 2012-02-07    184.190002
# 2012-02-08    185.479996
# 2012-02-09    184.979996
# 2012-02-10    185.539993
# 2012-02-13    191.589996
# 2012-02-14    191.300003
#                  ...
# 2015-11-18    663.539978
# 2015-11-19    661.270020
# 2015-11-20    668.450012
# ...

# %% [markdown]
# We can display the first few elements of our series by using the `head()` method and specifying the number of elements that we want. The analogous method for the last few elements is `tail()`.

# %%
#Se cambia la declaracion a Python3
print ("\n", type(prices))
prices.head(5)
# Out:
# ('\n', <class 'pandas.core.series.Series'>)
# Date
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-09    339.739990
# Name: Adj Close, dtype: float64

# %%
print ("\n", type(precios))
precios.head(10)
# Out:
# ('\n', <class 'pandas.core.series.Series'>)
# Date
# 2012-01-03    179.029999
# 2012-01-04    177.509995
# 2012-01-05    177.610001
# 2012-01-06    182.610001
# 2012-01-09    178.559998
# 2012-01-10    179.339996
# 2012-01-11    178.899994
# 2012-01-12    175.929993
# 2012-01-13    178.419998
# 2012-01-17    181.660004
# Name: Adj Close, dtype: float64

# %% [markdown]
# As with our toy example, we can specify a name for our time series, if only to clarify the name the `get_pricing()` provides us.

# %%
#se cambia la declaracion a Python3
print ('Old name: ', prices.name)
prices.name = symbol
print ('New name: ', prices.name)
# Out:
# ('Old name: ', 'Adj Close')
# ('New name: ', 'CMG')

# %%
print ('Nombre Viejo: ', precios.name)
precios.name = tck
print ('Nuevo Nombre: ', precios.name)
# Out:
# ('Nombre Viejo: ', 'Adj Close')
# ('Nuevo Nombre: ', 'AMZN')

# %% [markdown]
# Let's take a closer look at the `DatetimeIndex` of our `prices` time series.

# %%
#se cambia la declaracion a Python3
print (prices.index)
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2015-12-17', '2015-12-18', '2015-12-21', '2015-12-22',
#                '2015-12-23', '2015-12-24', '2015-12-28', '2015-12-29',
#                '2015-12-30', '2015-12-31'],
#               dtype='datetime64[ns]', name=u'Date', length=1006, freq=None)

# %%
print (precios.index)
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2015-12-17', '2015-12-18', '2015-12-21', '2015-12-22',
#                '2015-12-23', '2015-12-24', '2015-12-28', '2015-12-29',
#                '2015-12-30', '2015-12-31'],
#               dtype='datetime64[ns]', name=u'Date', length=1006, freq=None)

# %% [markdown]
# Notice that this `DatetimeIndex` has a collection of associated information. In particular it has an associated frequency (`freq`) and an associated timezone (`tz`). The frequency indicates whether the data is daily vs monthly vs some other period while the timezone indicates what locale this index is relative to. We can modify all of this extra information!
#
# If we resample our `Series`, we can adjust the frequency of our data. We currently have daily data (excluding weekends) because `get_pricing()` pulls only data from market days. Let's up-sample from this daily data to monthly data using the `resample()` method.

# %%
#Se agrega .mean() puesto que si en genera un error
monthly_prices = prices.resample('M').mean()
monthly_prices.head(10)
# Out:
# Date
# 2012-01-31    354.829002
# 2012-02-29    379.535503
# 2012-03-31    407.002272
# 2012-04-30    422.798998
# 2012-05-31    405.805456
# 2012-06-30    403.033335
# 2012-07-31    353.880474
# 2012-08-31    294.535219
# 2012-09-30    326.513160
# 2012-10-31    276.573333
# Freq: M, Name: CMG, dtype: float64

# %%
pm = precios.resample('M').mean()
pm.head(20)
# Out:
# Date
# 2012-01-31    185.027998
# 2012-02-29    183.242999
# 2012-03-31    189.534089
# 2012-04-30    195.291502
# 2012-05-31    220.884999
# 2012-06-30    219.274764
# 2012-07-31    224.062856
# 2012-08-31    238.993914
# 2012-09-30    255.740527
# 2012-10-31    244.294763
# 2012-11-30    234.422382
# 2012-12-31    252.818000
# 2013-01-31    268.379524
# 2013-02-28    263.697370
# 2013-03-31    265.758498
# 2013-04-30    263.072273
# 2013-05-31    262.727725
# 2013-06-30    274.102000
# 2013-07-31    298.976819
# 2013-08-31    291.153183
# Freq: M, Name: AMZN, dtype: float64

# %% [markdown]
# The `resample()` method defaults to using the mean of the lower level data to create the higher level data. We can specify how else we might want the up-sampling to be calculated by specifying the `how` parameter.

# %%
monthly_prices_med = prices.resample('M', how='median')
monthly_prices_med.head(10)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).median()
#   """Entry point for launching an IPython kernel.
# Date
# 2012-01-31    355.505005
# 2012-02-29    378.195007
# 2012-03-31    408.994996
# 2012-04-30    420.835007
# 2012-05-31    405.240006
# 2012-06-30    402.450012
# 2012-07-31    380.470001
# 2012-08-31    295.390015
# 2012-09-30    332.809998
# 2012-10-31    286.559998
# Freq: M, Name: CMG, dtype: float64

# %% [markdown]
# We can even specify how we want the calculation of the new period to be done. Here we create a `custom_resampler()` function that will return the first value of the period. In our specific case, this will return a `Series` where the monthly value is the first value of that month.

# %%
def custom_resampler(array_like):
    """ Returns the first value of the period """
    return array_like[0]

first_of_month_prices = prices.resample('M', how=custom_resampler)
first_of_month_prices.head(10)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   """
# Date
# 2012-01-31    341.269989
# 2012-02-29    370.410004
# 2012-03-31    394.100006
# 2012-04-30    418.399994
# 2012-05-31    419.890015
# 2012-06-30    397.140015
# 2012-07-31    383.459991
# 2012-08-31    280.670013
# 2012-09-30    285.989990
# 2012-10-31    316.130005
# Freq: M, Name: CMG, dtype: float64

# %%
def calculo_muestreo(array_like):
    """ Returns the first value of the period """
    return array_like[0:4]

pm_cinco = precios.resample('M', how=calculo_muestreo)
pm_cinco.head(15)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   """
# Date        Date
# 2012-01-31  2012-01-03    179.029999
#             2012-01-04    177.509995
#             2012-01-05    177.610001
#             2012-01-06    182.610001
# 2012-02-29  2012-02-01    179.460007
#             2012-02-02    181.720001
#             2012-02-03    187.679993
#             2012-02-06    183.139999
# 2012-03-31  2012-03-01    180.039993
#             2012-03-02    179.300003
#             2012-03-05    180.259995
#             2012-03-06    181.089996
# 2012-04-30  2012-04-02    198.050003
#             2012-04-03    199.660004
#             2012-04-04    193.990005
# Name: AMZN, dtype: float64

# %% [markdown]
# We can also adjust the timezone of a `Series` to adapt the time of real-world data. In our case, our time series is already localized to UTC, but let's say that we want to adjust the time to be 'US/Eastern'. In this case we use the `tz_convert()` method, since the time is already localized.

# %%
eastern_prices = prices.tz_localize('US/Eastern')
eastern_prices.head(10)
# Out:
# Date
# 2012-01-03 00:00:00-05:00    341.269989
# 2012-01-04 00:00:00-05:00    348.750000
# 2012-01-05 00:00:00-05:00    350.480011
# 2012-01-06 00:00:00-05:00    348.950012
# 2012-01-09 00:00:00-05:00    339.739990
# 2012-01-10 00:00:00-05:00    341.119995
# 2012-01-11 00:00:00-05:00    347.600006
# 2012-01-12 00:00:00-05:00    347.619995
# 2012-01-13 00:00:00-05:00    354.619995
# 2012-01-17 00:00:00-05:00    353.380005
# Name: CMG, dtype: float64

# %%
precio_costa_oriental = precios.tz_localize('US/Eastern')
precio_costa_oriental.head(20)
# Out:
# Date
# 2012-01-03 00:00:00-05:00    179.029999
# 2012-01-04 00:00:00-05:00    177.509995
# 2012-01-05 00:00:00-05:00    177.610001
# 2012-01-06 00:00:00-05:00    182.610001
# 2012-01-09 00:00:00-05:00    178.559998
# 2012-01-10 00:00:00-05:00    179.339996
# 2012-01-11 00:00:00-05:00    178.899994
# 2012-01-12 00:00:00-05:00    175.929993
# 2012-01-13 00:00:00-05:00    178.419998
# 2012-01-17 00:00:00-05:00    181.660004
# 2012-01-18 00:00:00-05:00    189.440002
# 2012-01-19 00:00:00-05:00    194.449997
# 2012-01-20 00:00:00-05:00    190.929993
# 2012-01-23 00:00:00-05:00    186.089996
# 2012-01-24 00:00:00-05:00    187.000000
# 2012-01-25 00:00:00-05:00    187.800003
# 2012-01-26 00:00:00-05:00    193.320007
# 2012-01-27 00:00:00-05:00    195.369995
# 2012-01-30 00:00:00-05:00    192.149994
# 2012-01-31 00:00:00-05:00    194.440002
# Name: AMZN, dtype: float64

# %% [markdown]
# In addition to the capacity for timezone and frequency management, each time series has a built-in `reindex()` method that we can use to realign the existing data according to a new set of index labels. If data does not exist for a particular label, the data will be filled with a placeholder value. This is typically `np.nan`, though we can provide a fill method.
#
# The data that we `get_pricing()` only includes market days. But what if we want prices for every single calendar day? This will include holidays and weekends, times when you normally cannot trade equities.  First let's create a new `DatetimeIndex` that contains all that we want.

# %%
#Se cambia la declaracion a Python3
calendar_dates = pd.date_range(start=start, end=end, freq='D')
print (calendar_dates)
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-02', '2012-01-03', '2012-01-04',
#                '2012-01-05', '2012-01-06', '2012-01-07', '2012-01-08',
#                '2012-01-09', '2012-01-10',
#                ...
#                '2015-12-23', '2015-12-24', '2015-12-25', '2015-12-26',
#                '2015-12-27', '2015-12-28', '2015-12-29', '2015-12-30',
#                '2015-12-31', '2016-01-01'],
#               dtype='datetime64[ns]', length=1462, freq='D')

# %%
fechas_calend = pd.date_range(inicio, fin, freq = 'D')
print (fechas_calend)
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=1828, freq='D')

# %% [markdown]
# Now let's use this new set of dates to reindex our time series. We tell the function that the fill method that we want is `ffill`. This denotes "forward fill". Any `NaN` values will be filled by the *last value* listed. So the price on the weekend or on a holiday will be listed as the price on the last market day that we know about.

# %%
calendar_prices = prices.reindex(calendar_dates, method='ffill')
calendar_prices.head(15)
# Out:
# 2012-01-01           NaN
# 2012-01-02           NaN
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-07    348.950012
# 2012-01-08    348.950012
# 2012-01-09    339.739990
# 2012-01-10    341.119995
# 2012-01-11    347.600006
# 2012-01-12    347.619995
# 2012-01-13    354.619995
# 2012-01-14    354.619995
# 2012-01-15    354.619995
# Freq: D, Name: CMG, dtype: float64

# %%
pc = precios.reindex(fechas_calend, method='ffill')
pc.head(15)
# Out:
# 2016-01-01    675.890015
# 2016-01-02    675.890015
# 2016-01-03    675.890015
# 2016-01-04    675.890015
# 2016-01-05    675.890015
# 2016-01-06    675.890015
# 2016-01-07    675.890015
# 2016-01-08    675.890015
# 2016-01-09    675.890015
# 2016-01-10    675.890015
# 2016-01-11    675.890015
# 2016-01-12    675.890015
# 2016-01-13    675.890015
# 2016-01-14    675.890015
# 2016-01-15    675.890015
# Freq: D, Name: AMZN, dtype: float64

# %% [markdown]
# You'll notice that we still have a couple of `NaN` values right at the beginning of our time series. This is because the first of January in 2012 was a Sunday and the second was a market holiday! Because these are the earliest data points and we don't have any information from before them, they cannot be forward-filled. We will take care of these `NaN` values in the next section, when we deal with missing data.

# %% [markdown]
# #### Missing Data
#
# Whenever we deal with real data, there is a very real possibility of encountering missing values. Real data is riddled with holes and pandas provides us with ways to handle them. Sometimes resampling or reindexing can create `NaN` values. Fortunately, pandas provides us with ways to handle them. We have two primary means of coping with missing data. The first of these is filling in the missing data with  `fillna()`. For example, say that we want to fill in the missing days with the mean price of all days.

# %%
meanfilled_prices = calendar_prices.fillna(calendar_prices.mean())
meanfilled_prices.head(10)
# Out:
# 2012-01-01    501.068185
# 2012-01-02    501.068185
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-07    348.950012
# 2012-01-08    348.950012
# 2012-01-09    339.739990
# 2012-01-10    341.119995
# Freq: D, Name: CMG, dtype: float64

# %%
#Completa los datos faltante con el promedio de todos los dias
pd_precios = pc.fillna(pc.mean())
pd_precios.head(20)
# Out:
# 2016-01-01    675.890015
# 2016-01-02    675.890015
# 2016-01-03    675.890015
# 2016-01-04    675.890015
# 2016-01-05    675.890015
# 2016-01-06    675.890015
# 2016-01-07    675.890015
# 2016-01-08    675.890015
# 2016-01-09    675.890015
# 2016-01-10    675.890015
# 2016-01-11    675.890015
# 2016-01-12    675.890015
# 2016-01-13    675.890015
# 2016-01-14    675.890015
# 2016-01-15    675.890015
# 2016-01-16    675.890015
# 2016-01-17    675.890015
# 2016-01-18    675.890015
# 2016-01-19    675.890015
# 2016-01-20    675.890015
# Freq: D, Name: AMZN, dtype: float64

# %% [markdown]
# Using `fillna()` is fairly easy. It is just a matter of indicating the value that you want to fill the spaces with. Unfortunately, this particular case doesn't make a whole lot of sense, for reasons discussed in the [lecture on stationarity](https://www.quantopian.com/lectures/integration-cointegration-and-stationarity) in the Lecture series. We could fill them with with $0$, simply, but that's similarly uninformative.
#
# Rather than filling in specific values, we can use the `method` parameter, similarly to how the `reindex()` method works. We could use "backward fill", where `NaN`s are filled with the *next* filled value (instead of forward fill's *last* filled value) like so:

# %%
bfilled_prices = calendar_prices.fillna(method='bfill')
bfilled_prices.head(10)
# Out:
# 2012-01-01    341.269989
# 2012-01-02    341.269989
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-07    348.950012
# 2012-01-08    348.950012
# 2012-01-09    339.739990
# 2012-01-10    341.119995
# Freq: D, Name: CMG, dtype: float64

# %%
ra_precios = pc.fillna(method='bfill')
ra_precios.head(20)
# Out:
# 2016-01-01    675.890015
# 2016-01-02    675.890015
# 2016-01-03    675.890015
# 2016-01-04    675.890015
# 2016-01-05    675.890015
# 2016-01-06    675.890015
# 2016-01-07    675.890015
# 2016-01-08    675.890015
# 2016-01-09    675.890015
# 2016-01-10    675.890015
# 2016-01-11    675.890015
# 2016-01-12    675.890015
# 2016-01-13    675.890015
# 2016-01-14    675.890015
# 2016-01-15    675.890015
# 2016-01-16    675.890015
# 2016-01-17    675.890015
# 2016-01-18    675.890015
# 2016-01-19    675.890015
# 2016-01-20    675.890015
# Freq: D, Name: AMZN, dtype: float64

# %% [markdown]
# But again, this is a bad idea for the same reasons as the previous option. Both of these so-called solutions take into account *future data* that was not available at the time of the data points that we are trying to fill. In the case of using the mean or the median, these summary statistics are calculated by taking into account the entire time series. Backward filling is equivalent to saying that the price of a particular security today, right now, tomorrow's price. This also makes no sense. These two options are both examples of look-ahead bias, using data that would be unknown or unavailable at the desired time, and should be avoided.
#
# Our next option is significantly more appealing. We could simply drop the missing data using the `dropna()` method. This is much better alternative than filling `NaN` values in with arbitrary numbers.

# %%
dropped_prices = calendar_prices.dropna()
dropped_prices.head(10)
# Out:
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-07    348.950012
# 2012-01-08    348.950012
# 2012-01-09    339.739990
# 2012-01-10    341.119995
# 2012-01-11    347.600006
# 2012-01-12    347.619995
# Freq: D, Name: CMG, dtype: float64

# %%
#Quita los valores desconocidos
quit_vd = pc.dropna()
quit_vd.head(20)
# Out:
# 2016-01-01    675.890015
# 2016-01-02    675.890015
# 2016-01-03    675.890015
# 2016-01-04    675.890015
# 2016-01-05    675.890015
# 2016-01-06    675.890015
# 2016-01-07    675.890015
# 2016-01-08    675.890015
# 2016-01-09    675.890015
# 2016-01-10    675.890015
# 2016-01-11    675.890015
# 2016-01-12    675.890015
# 2016-01-13    675.890015
# 2016-01-14    675.890015
# 2016-01-15    675.890015
# 2016-01-16    675.890015
# 2016-01-17    675.890015
# 2016-01-18    675.890015
# 2016-01-19    675.890015
# 2016-01-20    675.890015
# Freq: D, Name: AMZN, dtype: float64

# %% [markdown]
# Now our time series is cleaned for the calendar year, with all of our `NaN` values properly handled. It is time to talk about how to actually do time series analysis with pandas data structures.

# %% [markdown]
# #### Time Series Analysis with pandas
#
# Let's do some basic time series analysis on our original prices. Each pandas `Series` has a built-in plotting method.

# %%
prices.plot();
# We still need to add the axis labels and title ourselves
plt.title(symbol + " Prices")
plt.ylabel("Price")
plt.xlabel("Date");

# %%
precios.plot();
plt.title('Precios AMAZON')
plt.xlabel('Fechas')
plt.ylabel('Precios');

# %% [markdown]
# As well as some built-in descriptive statistics. We can either calculate these individually or using the `describe()` method.

# %% [markdown]
# Media aritmetica
# $${\displaystyle \mu ={\frac {1}{N}}\sum _{i=1}^{N}x_{i}} $$
#
# Población completa
# $${\displaystyle \sigma ={\sqrt {{\frac {1}{N}}\sum _{i=1}^{N}(x_{i}-\mu )^{2}}}}$$
#
# Muestra de una población
# $$
# {\displaystyle s={\sqrt {{\frac {1}{N-1}}\sum _{i=1}^{N}(x_{i}-\mu )^{2}}}}$$

# %%
#Se cambia la declaracion a Python3
print ("Mean: ", prices.mean())
print ("Standard deviation: ", prices.std())
# Out:
# ('Mean: ', 501.636650387674)
# ('Standard deviation: ', 146.68873795829842)

# %%
print ('Media: ', precios.mean())
print ('Desviacion Estandar: ', precios.std())
# Out:
# ('Media: ', 332.4787084950299)
# ('Desviacion Estandar: ', 112.2953479240693)

# %%
#Se cambia la declaracion a Python3
print ("Summary Statistics")
print (prices.describe())
# Out:
# Summary Statistics
# count    1006.000000
# mean      501.636650
# std       146.688738
# min       236.240005
# 25%       371.555001
# 50%       521.270019
# 75%       646.834991
# max       757.770020
# Name: CMG, dtype: float64

# %%
#Summary muestra un conjunto de datos de interes
print ('Resumen Estadistico')
print (precios.describe())
# Out:
# Resumen Estadistico
# count    1006.000000
# mean      332.478708
# std       112.295348
# min       175.929993
# 25%       257.915009
# 50%       310.039994
# 75%       375.140015
# max       693.969971
# Name: AMZN, dtype: float64

# %% [markdown]
# We can easily modify `Series` with scalars using our basic mathematical operators.

# %%
modified_prices = prices * 2 - 10
modified_prices.head(5)
# Out:
# Date
# 2012-01-03    672.539978
# 2012-01-04    687.500000
# 2012-01-05    690.960022
# 2012-01-06    687.900024
# 2012-01-09    669.479980
# Name: CMG, dtype: float64

# %%
cam_precios = precios / 5 + 10
cam_precios.head(10)
# Out:
# Date
# 2012-01-03    45.806000
# 2012-01-04    45.501999
# 2012-01-05    45.522000
# 2012-01-06    46.522000
# 2012-01-09    45.712000
# 2012-01-10    45.867999
# 2012-01-11    45.779999
# 2012-01-12    45.185999
# 2012-01-13    45.684000
# 2012-01-17    46.332001
# Name: AMZN, dtype: float64

# %% [markdown]
# And we can create linear combinations of `Series` themselves using the basic mathematical operators. pandas will group up matching indices and perform the calculations elementwise to produce a new `Series`.

# %%
noisy_prices = prices + 5 * pd.Series(np.random.normal(0, 5, len(prices)), index=prices.index) + 20
noisy_prices.head(5)
# Out:
# Date
# 2012-01-03    344.981829
# 2012-01-04    383.681866
# 2012-01-05    377.050496
# 2012-01-06    359.116754
# 2012-01-09    363.840769
# dtype: float64

# %%
cam_precios_2 = precios -10 * pd.Series(np.random.normal(0, 2.5, len(precios)), index=precios.index) / 10
cam_precios_2.head(10)
# Out:
# Date
# 2012-01-03    183.270917
# 2012-01-04    176.276544
# 2012-01-05    177.255090
# 2012-01-06    181.550189
# 2012-01-09    174.563660
# 2012-01-10    179.743625
# 2012-01-11    177.335940
# 2012-01-12    180.330473
# 2012-01-13    176.730306
# 2012-01-17    182.620411
# dtype: float64

# %% [markdown]
# If there are no matching indices, however, we may get an empty `Series` in return.

# %%
empty_series = prices + pd.Series(np.random.normal(0, 1, len(prices)))
empty_series.head(5)
# Out:
# 2012-01-03   NaN
# 2012-01-04   NaN
# 2012-01-05   NaN
# 2012-01-06   NaN
# 2012-01-09   NaN
# dtype: float64

# %%
serie_vacia = precios + pd.Series(np.random.normal(0, 1, len(precios)))
serie_vacia.head(10)
# Out:
# 2012-01-03   NaN
# 2012-01-04   NaN
# 2012-01-05   NaN
# 2012-01-06   NaN
# 2012-01-09   NaN
# 2012-01-10   NaN
# 2012-01-11   NaN
# 2012-01-12   NaN
# 2012-01-13   NaN
# 2012-01-17   NaN
# dtype: float64

# %% [markdown]
# Rather than looking at a time series itself, we may want to look at its first-order differences or percent change (in order to get additive or multiplicative returns, in our particular case). Both of these are built-in methods.

# %%
add_returns = prices.diff()[1:]
mult_returns = prices.pct_change()[1:]

# %%
ret_ad = precios.diff()[1:]
ret_mult = precios.pct_change()[1:]

# %%
plt.title("Multiplicative returns of " + symbol)
plt.xlabel("Date")
plt.ylabel("Percent Returns")
mult_returns.plot();

# %%
ret_mult.plot()
plt.title('Retornos Multiplicaticos de AMAZON')
plt.xlabel('Fecha')
plt.ylabel('Porcentaje de Retorno');

# %% [markdown]
# pandas has convenient functions for calculating rolling means and standard deviations, as well!

# %%
#rolling_mean = pd.rolling_mean(prices, 30)
rolling_mean = prices.rolling(30).mean()
rolling_mean.name = "30-day rolling mean"

# %%
media_movil = precios.rolling(60).mean()
media_movil.name = 'Media Movil de 60 dias'

# %%
prices.plot()
rolling_mean.plot()
plt.title(symbol + "Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend();

# %%
precios.plot()
media_movil.plot()
plt.title('Precio de AMAZON')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.legend();

# %%
rolling_std = prices.rolling(30).std()
#rolling_std = pd.rolling_std(prices, 30)
rolling_std.name = "30-day rolling volatility"

# %%
vol_movil = precios.rolling(60).std()
vol_movil.name = 'Volatilidad Movil De 60 Dias'

# %%
rolling_std.plot()
plt.title(rolling_std.name);
plt.xlabel("Date")
plt.ylabel("Standard Deviation");

# %%
vol_movil.plot()
plt.title(vol_movil.name);
plt.xlabel('Fecha')
plt.ylabel('Desviacion Estandar');

# %% [markdown]
# Many NumPy functions will work on `Series` the same way that they work on 1-dimensional NumPy arrays.

# %%
#Se cambia la declaracion a Python3 
print (np.median(mult_returns))
# Out:
# 0.00023590101519044282

# %%
print (np.median(ret_mult))
# Out:
# 0.0005380741282254853

# %% [markdown]
# The majority of these functions, however, are already implemented directly as `Series` and `DataFrame` methods.

# %%
#Se cambia la declaracion a Python3
print (mult_returns.median())
# Out:
# 0.00023590101519044282

# %%
print (ret_mult.median())
# Out:
# 0.0005380741282254853

# %% [markdown]
# In every case, using the built-in pandas method will be better than using the NumPy function on a pandas data structure due to improvements in performance. Make sure to check out the `Series` [documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html) before resorting to other calculations of common functions.

# %% [markdown]
# ### `DataFrames`
#
# Many of the aspects of working with `Series` carry over into `DataFrames`. pandas `DataFrames` allow us to easily manage our data with their intuitive structure.
#
# Like `Series`, `DataFrames` can hold multiple types of data, but `DataFrames` are 2-dimensional objects, unlike `Series`. Each `DataFrame` has an index and a columns attribute, which we will cover more in-depth when we start actually playing with an object. The index attribute is like the index of a `Series`, though indices in pandas have some extra features that we will unfortunately not be able to cover here. If you are interested in this, check out the [pandas documentation](http://pandas.pydata.org/pandas-docs/version/0.18.1/advanced.html) on advanced indexing. The columns attribute is what provides the second dimension of our `DataFrames`, allowing us to combine named columns (all `Series`), into a cohesive object with the index lined-up.
#
# We can create a `DataFrame` by calling `pandas.DataFrame()` on a dictionary or NumPy `ndarray`. We can also concatenate a group of pandas `Series` into a `DataFrame` using `pandas.concat()`.

# %%
#Se cambia la declaracion a Python3
dict_data = {
    'a' : [1, 2, 3, 4, 5],
    'b' : ['L', 'K', 'J', 'M', 'Z'],
    'c' : np.random.normal(0, 1, 5)
}
print (dict_data)
# Out:
# {'a': [1, 2, 3, 4, 5], 'c': array([-0.55257661, -0.2113359 ,  2.51204127,  0.14962013,  1.248088  ]), 'b': ['L', 'K', 'J', 'M', 'Z']}

# %%
dicc_datos = {
    'X_1' : [2, 4, 6, 8, 10],
    'X_2' : ['L', 'O', 'K', 'A', 'S'],
    'X_3' : np.random.normal(0, 1, 5)
}
print (dicc_datos)
# Out:
# {'X_2': ['L', 'O', 'K', 'A', 'S'], 'X_3': array([ 0.39065491,  0.62403423, -0.10236877, -1.10230515, -0.28089864]), 'X_1': [2, 4, 6, 8, 10]}

# %% [markdown]
# Each `DataFrame` has a few key attributes that we need to keep in mind. The first of these is the index attribute. We can easily include an index of `Timestamp` objects like we did with `Series`.

# %%
#Se cambia la declaracion a Python3
frame_data = pd.DataFrame(dict_data, index=pd.date_range('2016-01-01', periods=5))
print (frame_data)
# Out:
#             a  b         c
# 2016-01-01  1  L -0.552577
# 2016-01-02  2  K -0.211336
# 2016-01-03  3  J  2.512041
# 2016-01-04  4  M  0.149620
# 2016-01-05  5  Z  1.248088

# %%
fd = pd.DataFrame(dicc_datos, index=pd.date_range('2020-01-01', periods=5))
print (fd)
# Out:
#             X_1 X_2       X_3
# 2020-01-01    2   L  0.390655
# 2020-01-02    4   O  0.624034
# 2020-01-03    6   K -0.102369
# 2020-01-04    8   A -1.102305
# 2020-01-05   10   S -0.280899

# %% [markdown]
# As mentioned above, we can combine `Series` into `DataFrames`. Concatatenating `Series` like this will match elements up based on their corresponding index. As the following `Series` do not have an index assigned, they each default to an integer index.

# %%
#Se cambi la dclaracion a Python3
s_1 = pd.Series([2, 4, 6, 8, 10], name='Evens')
s_2 = pd.Series([1, 3, 5, 7, 9], name="Odds")
numbers = pd.concat([s_1, s_2], axis=1)
print (numbers)
# Out:
#    Evens  Odds
# 0      2     1
# 1      4     3
# 2      6     5
# 3      8     7
# 4     10     9

# %%
serie_1 = pd.Series([2, 4, 6, 8, 10], name='Pares')
serie_2 = pd.Series([1, 3, 5, 7, 9], name= 'Impares')
num = pd.concat([serie_1, serie_2], axis=1)
print (num)
# Out:
#    Pares  Impares
# 0      2        1
# 1      4        3
# 2      6        5
# 3      8        7
# 4     10        9

# %% [markdown]
# We will use `pandas.concat()` again later to combine multiple `DataFrame`s into one.

# %% [markdown]
# Each `DataFrame` also has a `columns` attribute. These can either be assigned when we call `pandas.DataFrame` or they can be modified directly like the index. Note that when we concatenated the two `Series` above, the column names were the names of those `Series`.

# %%
#Se cambia la declaracion a Python3
print (numbers.columns)
# Out:
# Index([u'Evens', u'Odds'], dtype='object')

# %%
print (num.columns)
# Out:
# Index([u'Pares', u'Impares'], dtype='object')

# %% [markdown]
# To modify the columns after object creation, we need only do the following:

# %%
#Se cambia la declaracion a Python3
numbers.columns = ['Shmevens', 'Shmodds']
print (numbers)
# Out:
#    Shmevens  Shmodds
# 0         2        1
# 1         4        3
# 2         6        5
# 3         8        7
# 4        10        9

# %%
num.columns = ['Col_1', 'Col_2']
print (num)
# Out:
#    Col_1  Col_2
# 0      2      1
# 1      4      3
# 2      6      5
# 3      8      7
# 4     10      9

# %% [markdown]
# In the same vein, the index of a `DataFrame` can be changed after the fact.

# %%
#Se cambia la declaracion a Python3
print (numbers.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print (num.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#Se cambia la declaracion a Python3
numbers.index = pd.date_range("2016-01-01", periods=len(numbers))
print (numbers)
# Out:
#             Shmevens  Shmodds
# 2016-01-01         2        1
# 2016-01-02         4        3
# 2016-01-03         6        5
# 2016-01-04         8        7
# 2016-01-05        10        9

# %%
num.index = pd.date_range('2020-01-01', periods=len(num))
print (num)
# Out:
#             Col_1  Col_2
# 2020-01-01      2      1
# 2020-01-02      4      3
# 2020-01-03      6      5
# 2020-01-04      8      7
# 2020-01-05     10      9

# %% [markdown]
# Separate from the columns and index of a `DataFrame`, we can also directly access the values they contain by looking at the values attribute.

# %%
numbers.values
# Out:
# array([[ 2,  1],
#        [ 4,  3],
#        [ 6,  5],
#        [ 8,  7],
#        [10,  9]])

# %%
num.values
# Out:
# array([[ 2,  1],
#        [ 4,  3],
#        [ 6,  5],
#        [ 8,  7],
#        [10,  9]])

# %% [markdown]
# This returns a NumPy array.

# %%
type(numbers.values)
# Out:
# numpy.ndarray

# %%
type(num.values)
# Out:
# numpy.ndarray

# %% [markdown]
# #### Accessing `DataFrame` elements
#
# Again we see a lot of carryover from `Series` in how we access the elements of `DataFrames`. The key sticking point here is that everything has to take into account multiple dimensions now. The main way that this happens is through the access of the columns of a `DataFrame`, either individually or in groups. We can do this either by directly accessing the attributes or by using the methods we already are familiar with.

# %%
symbol = ["CMG", "MCD", "SHAK"]
start = "2012-01-01"
end = "2016-01-01"
prices = pdr.get_data_yahoo(symbol, start, end)['Adj Close']

#prices = get_pricing(symbol, start_date=start, end_date=end, fields="price")
#if isinstance(symbol, list):
#    prices.columns = map(lambda x: x.symbol, prices.columns)
#else:
#    prices.name = symbol
prices
# Out:
# [*********************100%***********************]  3 of 3 downloaded
#                    CMG         MCD       SHAK
# Date
# 2012-01-03  341.269989   75.681129        NaN
# 2012-01-04  348.750000   76.102287        NaN
# 2012-01-05  350.480011   76.439156        NaN
# 2012-01-06  348.950012   77.028755        NaN
# 2012-01-09  339.739990   76.293686        NaN
# 2012-01-10  341.119995   76.339630        NaN
# 2012-01-11  347.600006   76.515724        NaN
# 2012-01-12  347.619995   77.005783        NaN
# 2012-01-13  354.619995   76.837326        NaN
# 2012-01-17  353.380005   76.990486        NaN
# 2012-01-18  356.820007   77.763817        NaN
# 2012-01-19  358.089996   77.534111        NaN
# 2012-01-20  356.390015   77.901634        NaN
# 2012-01-23  360.459991   77.296738        NaN
# 2012-01-24  360.600006   75.612228        NaN
# 2012-01-25  363.140015   75.979744        NaN
# 2012-01-26  365.809998   75.941467        NaN
# 2012-01-27  366.760010   75.566261        NaN
# ...

# %%
symbol = ["CMG", "MCD", "SHAK", "WFM", "AMZN"]
inicio = "2016-01-01"
final = "2020-01-01"
precios = pdr.get_data_yahoo(symbol, inicio, final)['Adj Close']
precios
# Out:
# [*********************100%***********************]  5 of 5 downloaded
#
# The following tickers failed to download:
#  WFM
#                    AMZN         CMG         MCD       SHAK
# Date
# 2016-01-04   636.989990  448.809998  102.686897  38.549999
# 2016-01-05   633.789978  449.029999  104.101669  39.009998
# 2016-01-06   632.650024  426.670013  103.403030  38.330002
# 2016-01-07   607.940002  416.000000  101.010094  36.200001
# 2016-01-08   607.049988  413.290009  100.852882  34.900002
# 2016-01-11   617.739990  411.100006  101.909607  34.209999
# 2016-01-12   617.890015  404.260010  102.564636  32.860001
# 2016-01-13   581.809998  428.279999  100.538475  31.920000
# 2016-01-14   593.000000  454.299988  101.848488  32.240002
# 2016-01-15   570.179993  475.940002  100.590874  32.070000
# 2016-01-19   574.479980  469.470001  102.617004  33.500000
# 2016-01-20   571.770020  465.500000  101.114868  33.750000
# 2016-01-21   575.020020  461.200012  102.913971  35.090000
# ...

# %% [markdown]
# Here we directly access the `CMG` column. Note that this style of access will only work if your column name has no spaces or unfriendly characters in it.

# %%
prices.CMG.head()
# Out:
# Date
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-09    339.739990
# Name: CMG, dtype: float64

# %%
precios.AMZN.head()
# Out:
# Date
# 2016-01-04    636.989990
# 2016-01-05    633.789978
# 2016-01-06    632.650024
# 2016-01-07    607.940002
# 2016-01-08    607.049988
# Name: AMZN, dtype: float64

# %% [markdown]
# We can also use `loc[]` to access an individual column like so.

# %%
prices.loc[:, 'CMG'].head()
# Out:
# Date
# 2012-01-03    341.269989
# 2012-01-04    348.750000
# 2012-01-05    350.480011
# 2012-01-06    348.950012
# 2012-01-09    339.739990
# Name: CMG, dtype: float64

# %%
precios.loc[:, 'AMZN'].head()
# Out:
# Date
# 2016-01-04    636.989990
# 2016-01-05    633.789978
# 2016-01-06    632.650024
# 2016-01-07    607.940002
# 2016-01-08    607.049988
# Name: AMZN, dtype: float64

# %% [markdown]
# Accessing an individual column will return a `Series`, regardless of how we get it.

# %%
#Se cambia la declaracion a Python3
print (type(prices.CMG))
print (type(prices.loc[:, 'CMG']))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
print (type(precios.AMZN))
print (type(precios.loc[:, 'AMZN']))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Notice how we pass a tuple into the `loc[]` method? This is a key difference between accessing a `Series` and accessing a `DataFrame`, grounded in the fact that a `DataFrame` has multiple dimensions. When you pass a 2-dimensional tuple into a `DataFrame`, the first element of the tuple is applied to the rows and the second is applied to the columns. So, to break it down, the above line of code tells the `DataFrame` to return every single row of the column with label `'CMG'`. Lists of columns are also supported.

# %%
prices.loc[:, ['CMG', 'MCD']].head()
# Out:
#                    CMG        MCD
# Date
# 2012-01-03  341.269989  75.681129
# 2012-01-04  348.750000  76.102287
# 2012-01-05  350.480011  76.439156
# 2012-01-06  348.950012  77.028755
# 2012-01-09  339.739990  76.293686

# %%
precios.loc[:, ['CMG', 'AMZN']].head()
# Out:
#                    CMG        AMZN
# Date
# 2016-01-04  448.809998  636.989990
# 2016-01-05  449.029999  633.789978
# 2016-01-06  426.670013  632.650024
# 2016-01-07  416.000000  607.940002
# 2016-01-08  413.290009  607.049988

# %% [markdown]
# We can also simply access the `DataFrame` by index value using `loc[]`, as with `Series`.

# %%
prices.loc['2015-12-15':'2015-12-22']
# Out:
#                    CMG         MCD       SHAK
# Date
# 2015-12-15  554.859985  102.119232  41.580002
# 2015-12-16  567.830017  102.913971  40.169998
# 2015-12-17  554.890015  102.617004  38.540001
# 2015-12-18  541.080017  101.883415  39.750000
# 2015-12-21  522.010010  102.782944  38.189999
# 2015-12-22  494.609985  102.809143  39.750000

# %%
precios.loc['2018-07-03':'2018-07-15']
# Out:
#                    AMZN         CMG         MCD       SHAK
# Date
# 2018-07-03  1693.959961  448.950012  146.339951  65.540001
# 2018-07-05  1699.729980  448.019989  147.125565  65.260002
# 2018-07-06  1710.630005  451.040009  149.089462  64.260002
# 2018-07-09  1739.020020  463.890015  149.575790  64.080002
# 2018-07-10  1743.069946  454.209991  150.211700  63.700001
# 2018-07-11  1755.000000  457.179993  148.341309  63.849998
# 2018-07-12  1796.619995  459.049988  148.808929  63.470001
# 2018-07-13  1813.030029  457.209991  148.238419  64.339996

# %% [markdown]
# This plays nicely with lists of columns, too.

# %%
prices.loc['2015-12-15':'2015-12-22', ['CMG', 'MCD']]
# Out:
#                    CMG         MCD
# Date
# 2015-12-15  554.859985  102.119232
# 2015-12-16  567.830017  102.913971
# 2015-12-17  554.890015  102.617004
# 2015-12-18  541.080017  101.883415
# 2015-12-21  522.010010  102.782944
# 2015-12-22  494.609985  102.809143

# %%
precios.loc['2018-07-03':'2018-07-15', ['AMZN', 'CMG']]
# Out:
#                    AMZN         CMG
# Date
# 2018-07-03  1693.959961  448.950012
# 2018-07-05  1699.729980  448.019989
# 2018-07-06  1710.630005  451.040009
# 2018-07-09  1739.020020  463.890015
# 2018-07-10  1743.069946  454.209991
# 2018-07-11  1755.000000  457.179993
# 2018-07-12  1796.619995  459.049988
# 2018-07-13  1813.030029  457.209991

# %% [markdown]
# Using `iloc[]` also works similarly, allowing you to access parts of the `DataFrame` by integer index.

# %%
prices.iloc[0:2, 1]
# Out:
# Date
# 2012-01-03    75.681129
# 2012-01-04    76.102287
# Name: MCD, dtype: float64

# %%
precios.iloc[0:5, -1]
# Out:
# Date
# 2016-01-04    38.549999
# 2016-01-05    39.009998
# 2016-01-06    38.330002
# 2016-01-07    36.200001
# 2016-01-08    34.900002
# Name: SHAK, dtype: float64

# %%
prices
# Out:
#                    CMG         MCD       SHAK
# Date
# 2012-01-03  341.269989   75.681129        NaN
# 2012-01-04  348.750000   76.102287        NaN
# 2012-01-05  350.480011   76.439156        NaN
# 2012-01-06  348.950012   77.028755        NaN
# 2012-01-09  339.739990   76.293686        NaN
# 2012-01-10  341.119995   76.339630        NaN
# 2012-01-11  347.600006   76.515724        NaN
# 2012-01-12  347.619995   77.005783        NaN
# 2012-01-13  354.619995   76.837326        NaN
# 2012-01-17  353.380005   76.990486        NaN
# 2012-01-18  356.820007   77.763817        NaN
# 2012-01-19  358.089996   77.534111        NaN
# 2012-01-20  356.390015   77.901634        NaN
# 2012-01-23  360.459991   77.296738        NaN
# 2012-01-24  360.600006   75.612228        NaN
# 2012-01-25  363.140015   75.979744        NaN
# 2012-01-26  365.809998   75.941467        NaN
# 2012-01-27  366.760010   75.566261        NaN
# 2012-01-30  367.690002   75.566261        NaN
# ...

# %%
# Access prices with integer index in
# [1, 3, 5, 7, 9, 11, 13, ..., 99]
# and in column 0 or 3
prices.iloc[[1, 3, 5] + range(7, 100, 2), [0, 2]].head(20)
# Out:
#                    CMG  SHAK
# Date
# 2012-01-04  348.750000   NaN
# 2012-01-06  348.950012   NaN
# 2012-01-10  341.119995   NaN
# 2012-01-12  347.619995   NaN
# 2012-01-17  353.380005   NaN
# 2012-01-19  358.089996   NaN
# 2012-01-23  360.459991   NaN
# 2012-01-25  363.140015   NaN
# 2012-01-27  366.760010   NaN
# 2012-01-31  367.290009   NaN
# 2012-02-02  362.820007   NaN
# 2012-02-06  371.630005   NaN
# 2012-02-08  374.019989   NaN
# 2012-02-10  376.450012   NaN
# 2012-02-14  378.940002   NaN
# 2012-02-16  382.040009   NaN
# 2012-02-21  383.579987   NaN
# 2012-02-23  386.799988   NaN
# 2012-02-27  388.890015   NaN
# 2012-02-29  390.220001   NaN

# %% [markdown]
# #### Boolean indexing
#
# As with `Series`, sometimes we want to filter a `DataFrame` according to a set of criteria. We do this by indexing our `DataFrame` with boolean values.

# %%
prices.loc[prices.MCD < prices.CMG].head()
# Out:
#                    CMG        MCD  SHAK
# Date
# 2012-01-03  341.269989  75.681129   NaN
# 2012-01-04  348.750000  76.102287   NaN
# 2012-01-05  350.480011  76.439156   NaN
# 2012-01-06  348.950012  77.028755   NaN
# 2012-01-09  339.739990  76.293686   NaN

# %%
precios.loc[precios.AMZN > precios.CMG].head()
# Out:
#                   AMZN         CMG         MCD       SHAK
# Date
# 2016-01-04  636.989990  448.809998  102.686897  38.549999
# 2016-01-05  633.789978  449.029999  104.101669  39.009998
# 2016-01-06  632.650024  426.670013  103.403030  38.330002
# 2016-01-07  607.940002  416.000000  101.010094  36.200001
# 2016-01-08  607.049988  413.290009  100.852882  34.900002

# %% [markdown]
# We can add multiple boolean conditions by using the logical operators `&`, `|`, and `~` (and, or, and not, respectively) again!

# %%
prices.loc[(prices.MCD < prices.CMG) & ~prices.SHAK.isnull()].head()
# Out:
#                    CMG        MCD       SHAK
# Date
# 2015-01-30  709.840027  78.041306  45.900002
# 2015-02-02  712.549988  78.100372  43.990002
# 2015-02-03  726.630005  79.290771  44.980000
# 2015-02-04  676.000000  79.400520  41.320000
# 2015-02-05  670.909973  79.645317  42.639999

# %%
precios.loc[((precios.SHAK > precios.MCD) & (precios.SHAK < precios.CMG)) < precios.AMZN].head()
# Out:
#                   AMZN         CMG         MCD       SHAK
# Date
# 2016-01-04  636.989990  448.809998  102.686897  38.549999
# 2016-01-05  633.789978  449.029999  104.101669  39.009998
# 2016-01-06  632.650024  426.670013  103.403030  38.330002
# 2016-01-07  607.940002  416.000000  101.010094  36.200001
# 2016-01-08  607.049988  413.290009  100.852882  34.900002

# %% [markdown]
# #### Adding, Removing Columns, Combining `DataFrames`/`Series`
#
# It is all well and good when you already have a `DataFrame` filled with data, but it is also important to be able to add to the data that you have.
#
# We add a new column simply by assigning data to a column that does not already exist. Here we use the `.loc[:, 'COL_NAME']` notation and store the output of `get_pricing()` (which returns a pandas `Series` if we only pass one security) there. This is the method that we would use to add a `Series` to an existing `DataFrame`.

# %%
#s_1 = get_pricing('TSLA', start_date=start, end_date=end, fields='price')
s_1 = pdr.get_data_yahoo('TSLA', start, end)['Adj Close']
prices.loc[:, 'TSLA'] = s_1
prices.head(5)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                    CMG        MCD  SHAK   TSLA
# Date
# 2012-01-03  341.269989  75.681129   NaN  5.616
# 2012-01-04  348.750000  76.102287   NaN  5.542
# 2012-01-05  350.480011  76.439156   NaN  5.424
# 2012-01-06  348.950012  77.028755   NaN  5.382
# 2012-01-09  339.739990  76.293686   NaN  5.450

# %%
ser_1 = pdr.get_data_yahoo('BABA', inicio, final)['Adj Close']
precios.loc[:, 'BABA'] = ser_1
precios.head(10)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                   AMZN         CMG         MCD       SHAK       BABA
# Date
# 2016-01-04  636.989990  448.809998  102.686897  38.549999  76.690002
# 2016-01-05  633.789978  449.029999  104.101669  39.009998  78.629997
# 2016-01-06  632.650024  426.670013  103.403030  38.330002  77.330002
# 2016-01-07  607.940002  416.000000  101.010094  36.200001  72.720001
# 2016-01-08  607.049988  413.290009  100.852882  34.900002  70.800003
# 2016-01-11  617.739990  411.100006  101.909607  34.209999  69.919998
# 2016-01-12  617.890015  404.260010  102.564636  32.860001  72.680000
# 2016-01-13  581.809998  428.279999  100.538475  31.920000  70.290001
# 2016-01-14  593.000000  454.299988  101.848488  32.240002  72.250000
# 2016-01-15  570.179993  475.940002  100.590874  32.070000  69.589996

# %% [markdown]
# It is also just as easy to remove a column.

# %%
prices = prices.drop('TSLA', axis=1)
prices.head(5)
# Out:
#                    CMG        MCD  SHAK
# Date
# 2012-01-03  341.269989  75.681129   NaN
# 2012-01-04  348.750000  76.102287   NaN
# 2012-01-05  350.480011  76.439156   NaN
# 2012-01-06  348.950012  77.028755   NaN
# 2012-01-09  339.739990  76.293686   NaN

# %%
precios = precios.drop('SHAK', axis = 1)
precios.head(10)
# Out:
#                   AMZN         CMG         MCD       BABA
# Date
# 2016-01-04  636.989990  448.809998  102.686897  76.690002
# 2016-01-05  633.789978  449.029999  104.101669  78.629997
# 2016-01-06  632.650024  426.670013  103.403030  77.330002
# 2016-01-07  607.940002  416.000000  101.010094  72.720001
# 2016-01-08  607.049988  413.290009  100.852882  70.800003
# 2016-01-11  617.739990  411.100006  101.909607  69.919998
# 2016-01-12  617.890015  404.260010  102.564636  72.680000
# 2016-01-13  581.809998  428.279999  100.538475  70.290001
# 2016-01-14  593.000000  454.299988  101.848488  72.250000
# 2016-01-15  570.179993  475.940002  100.590874  69.589996

# %% [markdown]
# If we instead want to combine multiple `DataFrame`s into one, we use the `pandas.concat()` method.

# %%
#df_1 = get_pricing(['SPY', 'VXX'], start_date=start, end_date=end, fields='price')
#Se remueve VXX ya que no aparecen datos
df_1 = pdr.get_data_yahoo(['SPY', 'INTC'], start, end)['Adj Close']
#df_2 = get_pricing(['MSFT', 'AAPL', 'GOOG'], start_date=start, end_date=end, fields='price')
df_2 = pdr.get_data_yahoo(['MSFT', 'AAPL', 'GOOG'], start, end)['Adj Close']
df_3 = pd.concat([df_1, df_2], axis=1)
df_3.head()
# Out:
# [*********************100%***********************]  2 of 2 downloaded
# [*********************100%***********************]  3 of 3 downloaded
#                  INTC         SPY       AAPL        GOOG       MSFT
# Date
# 2012-01-03  18.647131  106.680183  12.650659  331.462585  21.799267
# 2012-01-04  19.080259  106.847527  12.718646  332.892242  22.312283
# 2012-01-05  19.300613  107.132004  12.859850  328.274536  22.540291
# 2012-01-06  19.186634  106.855896  12.994284  323.796326  22.890448
# 2012-01-09  19.353809  107.115288  12.973674  310.067780  22.589146

# %%
d_f_1 = pdr.get_data_yahoo(['WMT', 'TXN'], inicio, final)['Adj Close']
d_f_2 = pdr.get_data_yahoo(['FB', 'GOOG', 'AAPL', 'KO'], inicio, final)['Adj Close']
d_f_3 = pd.concat([d_f_1, d_f_2], axis = 1)
d_f_3.head()
# Out:
# [*********************100%***********************]  2 of 2 downloaded
# [*********************100%***********************]  4 of 4 downloaded
#                   TXN        WMT       AAPL          FB        GOOG         KO
# Date
# 2016-01-04  47.249733  54.826603  24.364536  102.220001  741.840027  35.693829
# 2016-01-05  46.754116  56.129028  23.753977  102.730003  742.580017  35.820095
# 2016-01-06  46.449772  56.691048  23.289116  102.970001  743.619995  35.626476
# 2016-01-07  44.954205  58.011307  22.306208   97.919998  726.390015  35.037189
# 2016-01-08  43.789036  56.682114  22.424154   97.330002  714.469971  34.944588

# %% [markdown]
# #### Missing data (again)
# Bringing real-life data into a `DataFrame` brings us the same problems that we had with it in a `Series`, only this time in more dimensions. We have access to the same methods as with `Series`, as demonstrated below.

# %%
filled0_prices = prices.fillna(0)
filled0_prices.head(5)
# Out:
#                    CMG        MCD  SHAK
# Date
# 2012-01-03  341.269989  75.681129   0.0
# 2012-01-04  348.750000  76.102287   0.0
# 2012-01-05  350.480011  76.439156   0.0
# 2012-01-06  348.950012  77.028755   0.0
# 2012-01-09  339.739990  76.293686   0.0

# %%
fll0_precios = precios.fillna(0)
fll0_precios.head(10)
# Out:
#                   AMZN         CMG         MCD       BABA
# Date
# 2016-01-04  636.989990  448.809998  102.686897  76.690002
# 2016-01-05  633.789978  449.029999  104.101669  78.629997
# 2016-01-06  632.650024  426.670013  103.403030  77.330002
# 2016-01-07  607.940002  416.000000  101.010094  72.720001
# 2016-01-08  607.049988  413.290009  100.852882  70.800003
# 2016-01-11  617.739990  411.100006  101.909607  69.919998
# 2016-01-12  617.890015  404.260010  102.564636  72.680000
# 2016-01-13  581.809998  428.279999  100.538475  70.290001
# 2016-01-14  593.000000  454.299988  101.848488  72.250000
# 2016-01-15  570.179993  475.940002  100.590874  69.589996

# %%
bfilled_prices = prices.fillna(method='bfill')
bfilled_prices.head(5)

# %% [markdown]
# But again, the best choice in this case (since we are still using time series data, handling multiple time series at once) is still to simply drop the missing values.

# %%
dropped_prices = prices.dropna()
dropped_prices.head(5)
# Out:
#                    CMG        MCD       SHAK
# Date
# 2015-01-30  709.840027  78.041306  45.900002
# 2015-02-02  712.549988  78.100372  43.990002
# 2015-02-03  726.630005  79.290771  44.980000
# 2015-02-04  676.000000  79.400520  41.320000
# 2015-02-05  670.909973  79.645317  42.639999

# %%
dp_precios = precios.dropna()
dp_precios.head(10)
# Out:
#                   AMZN         CMG         MCD       BABA
# Date
# 2016-01-04  636.989990  448.809998  102.686897  76.690002
# 2016-01-05  633.789978  449.029999  104.101669  78.629997
# 2016-01-06  632.650024  426.670013  103.403030  77.330002
# 2016-01-07  607.940002  416.000000  101.010094  72.720001
# 2016-01-08  607.049988  413.290009  100.852882  70.800003
# 2016-01-11  617.739990  411.100006  101.909607  69.919998
# 2016-01-12  617.890015  404.260010  102.564636  72.680000
# 2016-01-13  581.809998  428.279999  100.538475  70.290001
# 2016-01-14  593.000000  454.299988  101.848488  72.250000
# 2016-01-15  570.179993  475.940002  100.590874  69.589996

# %% [markdown]
# #### Time Series Analysis with pandas
#
# Using the built-in statistics methods for `DataFrames`, we can perform calculations on multiple time series at once! The code to perform calculations on `DataFrames` here is almost exactly the same as the methods used for `Series` above, so don't worry about re-learning everything.
#
# The `plot()` method makes another appearance here, this time with a built-in legend that corresponds to the names of the columns that you are plotting.

# %%
prices.plot()
plt.title("Collected Stock Prices")
plt.ylabel("Price")
plt.xlabel("Date");

# %% [markdown]
# The same statistical functions from our interactions with `Series` resurface here with the addition of the `axis` parameter. By specifying the `axis`, we tell pandas to calculate the desired function along either the rows (`axis=0`) or the columns (`axis=1`). We can easily calculate the mean of each columns like so:

# %%
prices.mean(axis=0)
# Out:
# CMG     501.636650
# MCD      78.979400
# SHAK     53.575708
# dtype: float64

# %%
precios.mean(axis=0)
# Out:
# AMZN    1274.591153
# CMG      485.887306
# MCD      146.796300
# BABA     144.308678
# dtype: float64

# %% [markdown]
# As well as the standard deviation:

# %%
prices.std(axis=0)

# %%
precios.std(axis=0)
# Out:
# AMZN    472.903686
# CMG     156.002033
# MCD      32.440753
# BABA     42.757764
# dtype: float64

# %% [markdown]
# Again, the `describe()` function will provide us with summary statistics of our data if we would rather have all of our typical statistics in a convenient visual instead of calculating them individually.

# %%
prices.describe()
# Out:
#                CMG          MCD        SHAK
# count  1006.000000  1006.000000  233.000000
# mean    501.636650    78.979400   53.575708
# std     146.688738     6.699071   11.968587
# min     236.240005    65.829971   38.189999
# 25%     371.555001    75.829334   44.119999
# 50%     521.270019    78.654839   49.270000
# 75%     646.834991    82.062105   61.669998
# max     757.770020   104.861481   92.860001

# %%
precios.describe()
# Out:
#               AMZN          CMG          MCD         BABA
# count  1006.000000  1006.000000  1006.000000  1006.000000
# mean   1274.591153   485.887306   146.796300   144.308678
# std     472.903686   156.002033    32.440753    42.757764
# min     482.070007   251.330002    98.773216    60.570000
# 25%     818.517486   396.050004   112.237893   102.384998
# 50%    1194.714966   444.384995   148.361077   159.144996
# 75%    1749.964966   517.227478   171.927448   178.992500
# max    2039.510010   851.539978   212.002670   216.380005

# %% [markdown]
# We can scale and add scalars to our `DataFrame`, as you might suspect after dealing with `Series`. This again works element-wise.

# %%
(2 * prices - 50).head(5)
# Out:
#                    CMG         MCD  SHAK
# Date
# 2012-01-03  632.539978  101.362258   NaN
# 2012-01-04  647.500000  102.204574   NaN
# 2012-01-05  650.960022  102.878312   NaN
# 2012-01-06  647.900024  104.057510   NaN
# 2012-01-09  629.479980  102.587372   NaN

# %%
(100 * precios - 10).head(10)
# Out:
#                   AMZN         CMG         MCD       BABA
# Date
# 2016-01-04  63688.9990  44870.9998  10258.6897  7659.0002
# 2016-01-05  63368.9978  44892.9999  10400.1669  7852.9997
# 2016-01-06  63255.0024  42657.0013  10330.3030  7723.0002
# 2016-01-07  60784.0002  41590.0000  10091.0094  7262.0001
# 2016-01-08  60694.9988  41319.0009  10075.2882  7070.0003
# 2016-01-11  61763.9990  41100.0006  10180.9607  6981.9998
# 2016-01-12  61779.0015  40416.0010  10246.4636  7258.0000
# 2016-01-13  58170.9998  42817.9999  10043.8475  7019.0001
# 2016-01-14  59290.0000  45419.9988  10174.8488  7215.0000
# 2016-01-15  57007.9993  47584.0002  10049.0874  6948.9996

# %% [markdown]
# Here we use the `pct_change()` method to get a `DataFrame` of the multiplicative returns of the securities that we are looking at.

# %%
mult_returns = prices.pct_change()[1:]
mult_returns.head()
# Out:
#                  CMG       MCD  SHAK
# Date
# 2012-01-04  0.021918  0.005565   NaN
# 2012-01-05  0.004961  0.004427   NaN
# 2012-01-06 -0.004365  0.007713   NaN
# 2012-01-09 -0.026394 -0.009543   NaN
# 2012-01-10  0.004062  0.000602   NaN

# %%
ret_m = precios.pct_change()[1:]
ret_m.head(10)
# Out:
#                 AMZN       CMG       MCD      BABA
# Date
# 2016-01-05 -0.005024  0.000490  0.013778  0.025297
# 2016-01-06 -0.001799 -0.049796 -0.006711 -0.016533
# 2016-01-07 -0.039058 -0.025008 -0.023142 -0.059615
# 2016-01-08 -0.001464 -0.006514 -0.001556 -0.026403
# 2016-01-11  0.017610 -0.005299  0.010478 -0.012429
# 2016-01-12  0.000243 -0.016638  0.006428  0.039474
# 2016-01-13 -0.058392  0.059417 -0.019755 -0.032884
# 2016-01-14  0.019233  0.060755  0.013030  0.027884
# 2016-01-15 -0.038482  0.047634 -0.012348 -0.036817
# 2016-01-19  0.007541 -0.013594  0.020142  0.007760

# %% [markdown]
# If we use our statistics methods to standardize the returns, a common procedure when examining data, then we can get a better idea of how they all move relative to each other on the same scale.

# %%
norm_returns = (mult_returns - mult_returns.mean(axis=0))/mult_returns.std(axis=0)
norm_returns.loc['2014-01-01':'2015-01-01'].plot();

# %%
ret_n = (ret_m - ret_m.mean(axis=0))/ret_m.std(axis=0)
ret_n.loc['2016-01-01':'2016-12-31'].plot();

# %% [markdown]
# This makes it easier to compare the motion of the different time series contained in our example.

# %% [markdown]
# Rolling means and standard deviations also work with `DataFrames`.

# %%
#rolling_mean = pd.rolling_mean(prices, 30)
rolling_mean = prices.rolling(30).mean()
rolling_mean.columns = prices.columns

# %%
rm = precios.rolling(30).mean()
rm.columns = precios.columns

# %%
rolling_mean.plot()
plt.title("Rolling Mean of Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend();

# %%
rm.plot()
plt.title("Media Movil de los Precios")
plt.xlabel("Fecha")
plt.ylabel("Precio")
plt.legend();

# %% [markdown]
# For a complete list of all the methods that are built into `DataFrame`s, check out the [documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html).

# %% [markdown]
# # Next Steps
#
# Managing data gets a lot easier when you deal with pandas, though this has been a very general introduction. There are many more tools within the package which you may discover while trying to get your data to do precisely what you want. If you would rather read more on the additional capabilities of pandas, check out the [documentation](http://pandas.pydata.org/pandas-docs/stable/).

# %% [markdown]
# *This presentation is for informational purposes only and does not constitute an offer to sell, a solicitation to buy, or a recommendation for any security; nor does it constitute an offer to provide investment advisory or other services by Quantopian, Inc. ("Quantopian"). Nothing contained herein constitutes investment advice or offers any opinion with respect to the suitability of any security, and any views expressed herein should not be taken as advice to buy, sell, or hold any security or as an endorsement of any security or company.  In preparing the information contained herein, Quantopian, Inc. has not taken into account the investment needs, objectives, and financial circumstances of any particular investor. Any views expressed and data illustrated herein were prepared based upon information, believed to be reliable, available to Quantopian, Inc. at the time of publication. Quantopian makes no guarantees as to their accuracy or completeness. All information is subject to change and may quickly become unreliable for various reasons, including changes in market conditions or economic circumstances.*

# %% [markdown]
# "*   An Even Easier Guide to Getting Stock Data With Python [towardsdatascience](https://towardsdatascience.com/an-even-easier-guide-to-getting-stock-data-with-python-1a109df6b593)",
#
#  "*   Importando Datos Financieros en Python, con “pandas-datareader” [wordpress](https://programacionpython80889555.wordpress.com/2019/07/09/importando-datos-financieros-en-python-con-pandas-datareader/)",
#
# "*   Using yfinance (formerly fix_yahoo_finance) to Download Data [alphabench](https://alphabench.com/data/python-fix-yahoo-finance-tutorial.html)",
#
# "* Easiest Guide to Getting Stock Data With Python[towardsdatascience](https://towardsdatascience.com/easiest-guide-to-getting-stock-data-with-python-f74b5f75d179)"
